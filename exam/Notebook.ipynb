# %% [markdown]
# # Sajal Nepal
# # Bsc(Hons)Computing
# # University ID: c7683908
#
# I am submitting Exam Paper 2.

# %% [markdown]
# # My Programming Workflow
#
# ## Environment & Tools
# I work best with **Python** as my primary language, supported by VS Code as my editor. A *dark theme* and dual monitors help reduce eye strain during long coding sessions.
#
# ### Essential Tools
# - **Python** with virtual environments for project isolation
# - *Git* for version control and collaboration
# - **Jupyter Notebooks** for data exploration and prototyping
#
# ## Physical Setup
# A quiet, dedicated workspace with a comfortable chair is *crucial*. I prefer working in my home personal room when focus comes naturally, with **minimal distractions** nearby. Regular breaks and staying hydrated keep my productivity consistent throughout the day.

# %%
mark = int(input("Enter exam mark: "))
if mark >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %%
def has_coconut(strings):
    return "coconut" in strings

print(f"{has_coconut(['coconut'])}")
# Out:
# True
